# %%
# !pip install citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from scipy.stats import linregress
from citipy import citipy
from API_data import weather_api_key

# %%
coordinates = []
cities = []
city_api_data = []

lats = np.random.randint(-90,90,size=1400)
longs = np.random.randint(-180,180,size=1400)
coordinates = zip(lats,longs)

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# len(cities)

search_url = "http://api.openweathermap.org/data/2.5/find?q="
data_count = 0
for x, city in enumerate(cities):
    data_count = data_count + 1
    city_url = search_url + city + "&units=imperial&appid=" + weather_api_key
    print(f"Processing Record Number {data_count} for {city}")
    try:
        api_data = requests.get(city_url).json()
        
        city_lat = api_data["list"][0]["coord"]["lat"]
        city_temp = api_data["list"][0]["main"]["temp_max"]
        city_humidity = api_data["list"][0]["main"]["humidity"]
        city_cloudiness = api_data["list"][0]["clouds"]["all"]
        city_wind = api_data["list"][0]["wind"]["speed"]
        city_lon = api_data["list"][0]["coord"]["lon"]
        
        city_api_data.append({"City":city,"Lat":city_lat,"Lon":city_lon,"Temp":city_temp,"Humidity":city_humidity,"Cloudiness":city_cloudiness,"Wind Speed":city_wind})
    except:
        pass
# Out:
# Processing Record Number 1 for butaritari
# Processing Record Number 2 for norman wells
# Processing Record Number 3 for kapaa
# Processing Record Number 4 for cidreira
# Processing Record Number 5 for chokurdakh
# Processing Record Number 6 for rovaniemi
# Processing Record Number 7 for mar del plata
# Processing Record Number 8 for busselton
# Processing Record Number 9 for victoria
# Processing Record Number 10 for east london
# Processing Record Number 11 for butterworth
# Processing Record Number 12 for salalah
# Processing Record Number 13 for ust-tsilma
# Processing Record Number 14 for hobart
# Processing Record Number 15 for provideniya
# Processing Record Number 16 for mount isa
# Processing Record Number 17 for ushuaia
# Processing Record Number 18 for cabo san lucas
# Processing Record Number 19 for puerto escondido
# Processing Record Number 20 for kanchanaburi
# Processing Record Number 21 for wahran
# Processing Record Number 22 for la ronge
# Processing Record Number 23 for tashtyp
# Processing Record Number 24 for katete
# Processing Record Number 25 for thompson
# Processing Record Number 26 for hermanus
# Processing Record Number 27 for bengkulu
# Processing Record Number 28 for albany
# Processing Record Number 29 for xiongyue
# Processing Record Number 30 for qaanaaq
# Processing Record Number 31 for punta arenas
# Processing Record Number 32 for tasiilaq
# Processing Record Number 33 for hithadhoo
# Processing Record Number 34 for padang
# Processing Record Number 35 for poronaysk
# Processing Record Number 36 for lesogorskiy
# Processing Record Number 37 for mareeba
# Processing Record Number 38 for sabzevar
# Processing Record Number 39 for tutoia
# Processing Record Number 40 for tuktoyaktuk
# Processing Record Number 41 for nueva loja
# Processing Record Number 42 for saleaula
# Processing Record Number 43 for rikitea
# Processing Record Number 44 for hilo
# Processing Record Number 45 for pitimbu
# Processing Record Number 46 for antalaha
# Processing Record Number 47 for bathsheba
# Processing Record Number 48 for avarua
# Processing Record Number 49 for grand river south east
# Processing Record Number 50 for dali
# Processing Record Number 51 for vestmanna
# Processing Record Number 52 for georgetown
# Processing Record Number 53 for faya
# Processing Record Number 54 for khash
# Processing Record Number 55 for castro
# Processing Record Number 56 for marcona
# Processing Record Number 57 for nizhneyansk
# Processing Record Number 58 for fairbanks
# Processing Record Number 59 for sharjah
# Processing Record Number 60 for martapura
# Processing Record Number 61 for ginda
# Processing Record Number 62 for komsomolskiy
# Processing Record Number 63 for adrar
# Processing Record Number 64 for cape town
# Processing Record Number 65 for nabire
# Processing Record Number 66 for dikson
# Processing Record Number 67 for nichinan
# Processing Record Number 68 for bethel
# Processing Record Number 69 for kruisfontein
# Processing Record Number 70 for olafsvik
# Processing Record Number 71 for maniitsoq
# Processing Record Number 72 for port elizabeth
# Processing Record Number 73 for haines junction
# Processing Record Number 74 for ifakara
# Processing Record Number 75 for atuona
# Processing Record Number 76 for lapeer
# Processing Record Number 77 for ulkan
# Processing Record Number 78 for jamestown
# Processing Record Number 79 for lorengau
# Processing Record Number 80 for onega
# Processing Record Number 81 for fevralsk
# Processing Record Number 82 for sazonovo
# Processing Record Number 83 for arraial do cabo
# Processing Record Number 84 for kamyaran
# Processing Record Number 85 for fort saint john
# Processing Record Number 86 for jalu
# Processing Record Number 87 for kulhudhuffushi
# Processing Record Number 88 for upernavik
# Processing Record Number 89 for hue
# Processing Record Number 90 for torrington
# Processing Record Number 91 for taolanaro
# Processing Record Number 92 for vaini
# Processing Record Number 93 for raudeberg
# Processing Record Number 94 for bolungarvik
# Processing Record Number 95 for saskylakh
# Processing Record Number 96 for bredasdorp
# Processing Record Number 97 for henties bay
# Processing Record Number 98 for tautira
# Processing Record Number 99 for ribeira grande
# Processing Record Number 100 for longyearbyen
# Processing Record Number 101 for talnakh
# Processing Record Number 102 for mokhsogollokh
# Processing Record Number 103 for pontianak
# Processing Record Number 104 for kaeo
# Processing Record Number 105 for puerto ayora
# Processing Record Number 106 for hami
# Processing Record Number 107 for uyo
# Processing Record Number 108 for mahebourg
# Processing Record Number 109 for ituni
# Processing Record Number 110 for chapais
# Processing Record Number 111 for najran
# Processing Record Number 112 for faanui
# Processing Record Number 113 for vaitupu
# Processing Record Number 114 for lufilufi
# Processing Record Number 115 for naranjal
# Processing Record Number 116 for arlit
# Processing Record Number 117 for ballina
# Processing Record Number 118 for dien bien
# Processing Record Number 119 for nikolskoye
# Processing Record Number 120 for grindavik
# Processing Record Number 121 for samusu
# Processing Record Number 122 for yellowknife
# Processing Record Number 123 for touros
# Processing Record Number 124 for hasaki
# Processing Record Number 125 for cockburn town
# Processing Record Number 126 for san patricio
# Processing Record Number 127 for chuy
# Processing Record Number 128 for mataura
# Processing Record Number 129 for asau
# Processing Record Number 130 for sangmelima
# Processing Record Number 131 for kodiak
# Processing Record Number 132 for salekhard
# Processing Record Number 133 for ancud
# Processing Record Number 134 for clyde river
# Processing Record Number 135 for lumberton
# Processing Record Number 136 for vung tau
# Processing Record Number 137 for ixtapa
# Processing Record Number 138 for guerrero negro
# Processing Record Number 139 for punta gorda
# Processing Record Number 140 for narsaq
# Processing Record Number 141 for san jose
# Processing Record Number 142 for hambantota
# Processing Record Number 143 for ponta do sol
# Processing Record Number 144 for souillac
# Processing Record Number 145 for leningradskiy
# Processing Record Number 146 for santa maria
# Processing Record Number 147 for guilin
# Processing Record Number 148 for kurilsk
# Processing Record Number 149 for saint-philippe
# Processing Record Number 150 for falealupo
# Processing Record Number 151 for bolshegrivskoye
# Processing Record Number 152 for attawapiskat
# Processing Record Number 153 for san joaquin
# Processing Record Number 154 for shimoda
# Processing Record Number 155 for isangel
# Processing Record Number 156 for pullampadi
# Processing Record Number 157 for ojinaga
# Processing Record Number 158 for batemans bay
# Processing Record Number 159 for nanortalik
# Processing Record Number 160 for dzhebariki-khaya
# Processing Record Number 161 for srednekolymsk
# Processing Record Number 162 for bialogard
# Processing Record Number 163 for laguna
# Processing Record Number 164 for chagda
# Processing Record Number 165 for atasu
# Processing Record Number 166 for tukrah
# Processing Record Number 167 for te anau
# Processing Record Number 168 for beisfjord
# Processing Record Number 169 for bend
# Processing Record Number 170 for west lake stevens
# Processing Record Number 171 for tarakan
# Processing Record Number 172 for andenes
# Processing Record Number 173 for sapucaia
# Processing Record Number 174 for klaksvik
# Processing Record Number 175 for nome
# Processing Record Number 176 for vaitape
# Processing Record Number 177 for neryungri
# Processing Record Number 178 for bahia honda
# Processing Record Number 179 for bluff
# Processing Record Number 180 for grand gaube
# Processing Record Number 181 for broken hill
# Processing Record Number 182 for tazovskiy
# Processing Record Number 183 for disna
# Processing Record Number 184 for lebu
# Processing Record Number 185 for new norfolk
# Processing Record Number 186 for waddan
# Processing Record Number 187 for severo-kurilsk
# Processing Record Number 188 for vardo
# Processing Record Number 189 for ostrovnoy
# Processing Record Number 190 for nuqui
# Processing Record Number 191 for waingapu
# Processing Record Number 192 for remanso
# Processing Record Number 193 for kachiry
# Processing Record Number 194 for necochea
# Processing Record Number 195 for vila velha
# Processing Record Number 196 for abha
# Processing Record Number 197 for grand centre
# Processing Record Number 198 for narok
# Processing Record Number 199 for bambous virieux
# Processing Record Number 200 for torbay
# Processing Record Number 201 for salisbury
# Processing Record Number 202 for siguiri
# Processing Record Number 203 for okha
# Processing Record Number 204 for barentsburg
# Processing Record Number 205 for aleksandrov gay
# Processing Record Number 206 for port alfred
# Processing Record Number 207 for zhigansk
# Processing Record Number 208 for vilhena
# Processing Record Number 209 for ridgecrest
# Processing Record Number 210 for mys shmidta
# Processing Record Number 211 for khovu-aksy
# Processing Record Number 212 for shelburne
# Processing Record Number 213 for dunmore east
# Processing Record Number 214 for zhob
# Processing Record Number 215 for vyazemskiy
# Processing Record Number 216 for bonito
# Processing Record Number 217 for dryden
# Processing Record Number 218 for sibolga
# Processing Record Number 219 for kassala
# Processing Record Number 220 for adelaide
# Processing Record Number 221 for lazaro cardenas
# Processing Record Number 222 for los llanos de aridane
# Processing Record Number 223 for kavieng
# Processing Record Number 224 for haldia
# Processing Record Number 225 for ucluelet
# Processing Record Number 226 for doka
# Processing Record Number 227 for belaya gora
# Processing Record Number 228 for honningsvag
# Processing Record Number 229 for havre-saint-pierre
# Processing Record Number 230 for sorland
# Processing Record Number 231 for huambo
# Processing Record Number 232 for katsuura
# Processing Record Number 233 for bandarbeyla
# Processing Record Number 234 for aljezur
# Processing Record Number 235 for tiksi
# Processing Record Number 236 for eureka
# Processing Record Number 237 for egvekinot
# Processing Record Number 238 for andarab
# Processing Record Number 239 for kunigal
# Processing Record Number 240 for tuatapere
# Processing Record Number 241 for sur
# Processing Record Number 242 for barcelos
# Processing Record Number 243 for illoqqortoormiut
# Processing Record Number 244 for beringovskiy
# Processing Record Number 245 for coahuayana
# Processing Record Number 246 for brumunddal
# Processing Record Number 247 for sorvag
# Processing Record Number 248 for linxia
# Processing Record Number 249 for broome
# Processing Record Number 250 for mitu
# Processing Record Number 251 for alofi
# Processing Record Number 252 for vostok
# Processing Record Number 253 for pevek
# Processing Record Number 254 for deh rawud
# Processing Record Number 255 for nuevo ideal
# Processing Record Number 256 for tamsweg
# Processing Record Number 257 for paita
# Processing Record Number 258 for manggar
# Processing Record Number 259 for port lincoln
# Processing Record Number 260 for belushya guba
# Processing Record Number 261 for san quintin
# Processing Record Number 262 for san antonio
# Processing Record Number 263 for constitucion
# Processing Record Number 264 for hamilton
# Processing Record Number 265 for williams lake
# Processing Record Number 266 for nueva imperial
# Processing Record Number 267 for kargasok
# Processing Record Number 268 for jiddah
# Processing Record Number 269 for kongolo
# Processing Record Number 270 for bokoro
# Processing Record Number 271 for rupert
# Processing Record Number 272 for seymchan
# Processing Record Number 273 for kushiro
# Processing Record Number 274 for luderitz
# Processing Record Number 275 for lucea
# Processing Record Number 276 for grand-santi
# Processing Record Number 277 for zeya
# Processing Record Number 278 for pokhara
# Processing Record Number 279 for taoudenni
# Processing Record Number 280 for san cristobal
# Processing Record Number 281 for whitehorse
# Processing Record Number 282 for hovd
# Processing Record Number 283 for kudahuvadhoo
# Processing Record Number 284 for ilulissat
# Processing Record Number 285 for port hardy
# Processing Record Number 286 for tokonou
# Processing Record Number 287 for burica
# Processing Record Number 288 for prince rupert
# Processing Record Number 289 for garowe
# Processing Record Number 290 for chardara
# Processing Record Number 291 for tizimin
# Processing Record Number 292 for natal
# Processing Record Number 293 for san policarpo
# Processing Record Number 294 for kochi
# Processing Record Number 295 for barrow
# Processing Record Number 296 for carnarvon
# Processing Record Number 297 for yumen
# Processing Record Number 298 for del rio
# Processing Record Number 299 for qandala
# Processing Record Number 300 for kirakira
# Processing Record Number 301 for zhangye
# Processing Record Number 302 for yerbogachen
# Processing Record Number 303 for kaitangata
# Processing Record Number 304 for nelson bay
# Processing Record Number 305 for barmer
# Processing Record Number 306 for saint-augustin
# Processing Record Number 307 for sept-iles
# Processing Record Number 308 for meulaboh
# Processing Record Number 309 for vila
# Processing Record Number 310 for inndyr
# Processing Record Number 311 for maldonado
# Processing Record Number 312 for lodja
# Processing Record Number 313 for cherskiy
# Processing Record Number 314 for rio grande
# Processing Record Number 315 for poum
# Processing Record Number 316 for wanaka
# Processing Record Number 317 for saldanha
# Processing Record Number 318 for anadyr
# Processing Record Number 319 for belmonte
# Processing Record Number 320 for airai
# Processing Record Number 321 for namatanai
# Processing Record Number 322 for goure
# Processing Record Number 323 for sao filipe
# Processing Record Number 324 for kawhia
# Processing Record Number 325 for nishihara
# Processing Record Number 326 for mahibadhoo
# Processing Record Number 327 for haimen
# Processing Record Number 328 for rafai
# Processing Record Number 329 for whakatane
# Processing Record Number 330 for shache
# Processing Record Number 331 for muros
# Processing Record Number 332 for torata
# Processing Record Number 333 for shingu
# Processing Record Number 334 for kloulklubed
# Processing Record Number 335 for pizarro
# Processing Record Number 336 for husavik
# Processing Record Number 337 for katakwi
# Processing Record Number 338 for abeche
# Processing Record Number 339 for roald
# Processing Record Number 340 for banjar
# Processing Record Number 341 for palu
# Processing Record Number 342 for nador
# Processing Record Number 343 for ketchikan
# Processing Record Number 344 for lind
# Processing Record Number 345 for villamontes
# Processing Record Number 346 for tornio
# Processing Record Number 347 for vallenar
# Processing Record Number 348 for bundaberg
# Processing Record Number 349 for bilibino
# Processing Record Number 350 for champerico
# Processing Record Number 351 for mandalgovi
# Processing Record Number 352 for pisco
# Processing Record Number 353 for palabuhanratu
# Processing Record Number 354 for bratsk
# Processing Record Number 355 for tateyama
# Processing Record Number 356 for camaragibe
# Processing Record Number 357 for praia da vitoria
# Processing Record Number 358 for kutum
# Processing Record Number 359 for aasiaat
# Processing Record Number 360 for harqalah
# Processing Record Number 361 for vestmannaeyjar
# Processing Record Number 362 for flin flon
# Processing Record Number 363 for kiruna
# Processing Record Number 364 for nemuro
# Processing Record Number 365 for port macquarie
# Processing Record Number 366 for sentyabrskiy
# Processing Record Number 367 for kavant
# Processing Record Number 368 for azul
# Processing Record Number 369 for urucara
# Processing Record Number 370 for kasongo-lunda
# Processing Record Number 371 for lugovoy
# Processing Record Number 372 for gamba
# Processing Record Number 373 for virginia beach
# Processing Record Number 374 for bone
# Processing Record Number 375 for namibe
# Processing Record Number 376 for pamanukan
# Processing Record Number 377 for bainbridge
# Processing Record Number 378 for biak
# Processing Record Number 379 for salvacion
# Processing Record Number 380 for nalgonda
# Processing Record Number 381 for gold coast
# Processing Record Number 382 for amboise
# Processing Record Number 383 for reconquista
# Processing Record Number 384 for pringsewu
# Processing Record Number 385 for pousat
# Processing Record Number 386 for trincomalee
# Processing Record Number 387 for blackwater
# Processing Record Number 388 for richards bay
# Processing Record Number 389 for brae
# Processing Record Number 390 for qingdao
# Processing Record Number 391 for muisne
# Processing Record Number 392 for rakiv lis
# Processing Record Number 393 for am timan
# Processing Record Number 394 for mehamn
# Processing Record Number 395 for ajdabiya
# Processing Record Number 396 for geraldton
# Processing Record Number 397 for ust-kamchatsk
# Processing Record Number 398 for saint-georges
# Processing Record Number 399 for dalneye konstantinovo
# Processing Record Number 400 for tecpan
# Processing Record Number 401 for sholavandan
# Processing Record Number 402 for hofn
# Processing Record Number 403 for sao joao da barra
# Processing Record Number 404 for yar-sale
# Processing Record Number 405 for riyaq
# Processing Record Number 406 for burns lake
# Processing Record Number 407 for sitka
# Processing Record Number 408 for mackenzie
# Processing Record Number 409 for lagoa
# Processing Record Number 410 for tello
# Processing Record Number 411 for flinders
# Processing Record Number 412 for coquimbo
# Processing Record Number 413 for itupiranga
# Processing Record Number 414 for fraserburgh
# Processing Record Number 415 for dzhusaly
# Processing Record Number 416 for dourbali
# Processing Record Number 417 for karratha
# Processing Record Number 418 for tahoua
# Processing Record Number 419 for khatanga
# Processing Record Number 420 for alice springs
# Processing Record Number 421 for ondangwa
# Processing Record Number 422 for rapid valley
# Processing Record Number 423 for malindi
# Processing Record Number 424 for madingou
# Processing Record Number 425 for meridian
# Processing Record Number 426 for pemba
# Processing Record Number 427 for yook
# Processing Record Number 428 for atar
# Processing Record Number 429 for matara
# Processing Record Number 430 for erenhot
# Processing Record Number 431 for pangnirtung
# Processing Record Number 432 for copaceni
# Processing Record Number 433 for port blair
# Processing Record Number 434 for udachnyy
# Processing Record Number 435 for olga
# Processing Record Number 436 for codrington
# Processing Record Number 437 for wairoa
# Processing Record Number 438 for tarudant
# Processing Record Number 439 for roebourne
# Processing Record Number 440 for iskateley
# Processing Record Number 441 for esperance
# Processing Record Number 442 for awjilah
# Processing Record Number 443 for cocobeach
# Processing Record Number 444 for pacific grove
# Processing Record Number 445 for ambon
# Processing Record Number 446 for pimentel
# Processing Record Number 447 for mercedes
# Processing Record Number 448 for rancho palos verdes
# Processing Record Number 449 for mastic beach
# Processing Record Number 450 for morondava
# Processing Record Number 451 for tongchuan
# Processing Record Number 452 for dianopolis
# Processing Record Number 453 for sioux lookout
# Processing Record Number 454 for laizhou
# Processing Record Number 455 for primore
# Processing Record Number 456 for lillooet
# Processing Record Number 457 for ust-ilimsk
# Processing Record Number 458 for quepos
# Processing Record Number 459 for comodoro rivadavia
# Processing Record Number 460 for kathmandu
# Processing Record Number 461 for codo
# Processing Record Number 462 for bairiki
# Processing Record Number 463 for dejen
# Processing Record Number 464 for bowen
# Processing Record Number 465 for abilene
# Processing Record Number 466 for nyamuswa
# Processing Record Number 467 for saint george
# Processing Record Number 468 for aykhal
# Processing Record Number 469 for navoi
# Processing Record Number 470 for mujiayingzi
# Processing Record Number 471 for emerald
# Processing Record Number 472 for vao
# Processing Record Number 473 for pilar
# Processing Record Number 474 for ndago
# Processing Record Number 475 for bababe
# Processing Record Number 476 for andevoranto
# Processing Record Number 477 for daru
# Processing Record Number 478 for dzaoudzi
# Processing Record Number 479 for tura
# Processing Record Number 480 for kerchevskiy
# Processing Record Number 481 for ustyuzhna
# Processing Record Number 482 for vega de alatorre
# Processing Record Number 483 for kantang
# Processing Record Number 484 for vedeno
# Processing Record Number 485 for cayenne
# Processing Record Number 486 for barvinkove
# Processing Record Number 487 for le port
# Processing Record Number 488 for baherden
# Processing Record Number 489 for srandakan
# Processing Record Number 490 for bull savanna
# Processing Record Number 491 for baykit
# Processing Record Number 492 for batagay-alyta
# Processing Record Number 493 for vazhiny
# Processing Record Number 494 for atka
# Processing Record Number 495 for blensong
# Processing Record Number 496 for sao geraldo do araguaia
# Processing Record Number 497 for urdoma
# Processing Record Number 498 for anshun
# Processing Record Number 499 for manta
# Processing Record Number 500 for dakar
# Processing Record Number 501 for raga
# Processing Record Number 502 for petropavlovsk-kamchatskiy
# Processing Record Number 503 for anloga
# Processing Record Number 504 for chichibu
# Processing Record Number 505 for yingcheng
# Processing Record Number 506 for partyzany
# Processing Record Number 507 for buchanan
# Processing Record Number 508 for angoche
# Processing Record Number 509 for touba
# Processing Record Number 510 for tiebissou
# Processing Record Number 511 for kamenskoye
# Processing Record Number 512 for masindi
# Processing Record Number 513 for pangkalanbuun
# Processing Record Number 514 for tucano
# Processing Record Number 515 for leshan
# Processing Record Number 516 for porto novo
# Processing Record Number 517 for ordubad
# Processing Record Number 518 for kaya
# Processing Record Number 519 for bacalar
# Processing Record Number 520 for conde
# Processing Record Number 521 for sudak
# Processing Record Number 522 for manavalakurichi
# Processing Record Number 523 for hualmay
# Processing Record Number 524 for shenzhen
# Processing Record Number 525 for hanna
# Processing Record Number 526 for el triunfo
# Processing Record Number 527 for belyy yar
# Processing Record Number 528 for bonthe
# Processing Record Number 529 for divnomorskoye
# Processing Record Number 530 for mayumba
# Processing Record Number 531 for cangucu
# Processing Record Number 532 for culiacan
# Processing Record Number 533 for westport
# Processing Record Number 534 for tabuk
# Processing Record Number 535 for olbia
# Processing Record Number 536 for bereda
# Processing Record Number 537 for sennoy
# Processing Record Number 538 for rawson
# Processing Record Number 539 for rungata
# Processing Record Number 540 for iqaluit
# Processing Record Number 541 for sarh
# Processing Record Number 542 for saint-francois
# Processing Record Number 543 for forestville
# Processing Record Number 544 for tsumeb
# Processing Record Number 545 for santa cruz
# Processing Record Number 546 for socorro
# Processing Record Number 547 for ceuta
# Processing Record Number 548 for one hundred mile house
# Processing Record Number 549 for navahrudak
# Processing Record Number 550 for pirenopolis
# Processing Record Number 551 for kommunar
# Processing Record Number 552 for troitskoye
# Processing Record Number 553 for gorontalo
# Processing Record Number 554 for lasa
# Processing Record Number 555 for lengshuitan
# Processing Record Number 556 for okhotsk
# Processing Record Number 557 for talwara
# Processing Record Number 558 for college
# Processing Record Number 559 for tsybuliv
# Processing Record Number 560 for paducah
# Processing Record Number 561 for chauk
# Processing Record Number 562 for dudinka
# Processing Record Number 563 for gimli
# Processing Record Number 564 for west plains
# Processing Record Number 565 for naryan-mar
# Processing Record Number 566 for burnie
# Processing Record Number 567 for fortuna
# Processing Record Number 568 for teguldet
# Processing Record Number 569 for sao jose da coroa grande
# Processing Record Number 570 for murgab
# Processing Record Number 571 for catuday
# Processing Record Number 572 for lompoc
# Processing Record Number 573 for aklavik
# Processing Record Number 574 for asayita
# Processing Record Number 575 for sertanopolis
# Processing Record Number 576 for dirba
# Processing Record Number 577 for tumannyy
# Processing Record Number 578 for cravo norte
# Processing Record Number 579 for bluefields
# Processing Record Number 580 for stoyba
# Processing Record Number 581 for tanshui
# Processing Record Number 582 for pahrump
# Processing Record Number 583 for guiyang
# Processing Record Number 584 for mazamitla

# %%
city_data_df = pd.DataFrame(city_api_data)
output_csv = "./city_output_data/city_data.csv"
city_data_df.to_csv(output_csv,index_label="City Number")
print(city_data_df.count())
city_data_df.head()
# Out:
# City          533
# Lat           533
# Lon           533
# Temp          533
# Humidity      533
# Cloudiness    533
# Wind Speed    533
# dtype: int64
#            City      Lat       Lon   Temp  Humidity  Cloudiness  Wind Speed
# 0    butaritari   3.0707  172.7902  83.37        76          11       12.75
# 1  norman wells  65.2820 -126.8329  55.40        66          75       10.29
# 2         kapaa  22.0752 -159.3190  80.60        69          40       12.75
# 3      cidreira -30.1811  -50.2056  55.96        80         100        9.04
# 4    chokurdakh  70.6333  147.9167  41.00        93          99        9.13

# %%
# Latitude vs Temp scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Temp"])
plt.title("Latitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("city_output_data/Scatter_1.png")

# %%
# Latitude vs Humidity scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"])
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("city_output_data/Scatter_2.png")

# %%
# Latitude vs Cloudiness scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"])
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness)")
plt.savefig("city_output_data/Scatter_3.png")

# %%
# Latitude vs Wind Speed scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"])
plt.title("Latitude vs Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.savefig("city_output_data/Scatter_4.png")

# %%
# Northern Hemisphere Temp vs Latitude linear regression

# %%
# Southern Hemisphere Temp vs Latitude linear regression

# %%
# Northern Hemisphere Humidity vs Latitude linear regression

# %%
# Southern Hemisphere Humidity vs Latitude linear regression

# %%
# Northern Hemisphere Cloudiness vs Latitude linear regression

# %%
# Southern Hemisphere Cloudiness vs Latitude linear regression

# %%
# Northern Hemisphere Wind Speed vs Latitude linear regression

# %%
# Southern Hemisphere Wind Speed vs Latitude linear regression
