# %%
# !pip install citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import scipy.stats as st
from citipy import citipy
from API_data import weather_api_key

# %%
coordinates = []
cities = []
city_api_data = []

lats = np.random.randint(-90,90,size=1400)
longs = np.random.randint(-180,180,size=1400)
coordinates = zip(lats,longs)

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# len(cities)

search_url = "http://api.openweathermap.org/data/2.5/find?q="
data_count = 0
for x, city in enumerate(cities):
    data_count = data_count + 1
    city_url = search_url + city + "&units=imperial&appid=" + weather_api_key
    print(f"Processing Record Number {data_count} for {city}")
    try:
        api_data = requests.get(city_url).json()
        
        city_lat = api_data["list"][0]["coord"]["lat"]
        city_temp = api_data["list"][0]["main"]["temp_max"]
        city_humidity = api_data["list"][0]["main"]["humidity"]
        city_cloudiness = api_data["list"][0]["clouds"]["all"]
        city_wind = api_data["list"][0]["wind"]["speed"]
        city_lon = api_data["list"][0]["coord"]["lon"]
        city_country = api_data["list"][0]["sys"]["country"]
        
        city_api_data.append({"City":city,"Lat":city_lat,"Lon":city_lon,"Temp":city_temp,"Humidity":city_humidity,"Cloudiness":city_cloudiness,"Wind Speed":city_wind,"Country":city_country})
    except:
        pass
# Out:
# Processing Record Number 1 for avarua
# Processing Record Number 2 for baykit
# Processing Record Number 3 for bako
# Processing Record Number 4 for east london
# Processing Record Number 5 for bredasdorp
# Processing Record Number 6 for middleton
# Processing Record Number 7 for broome
# Processing Record Number 8 for pevek
# Processing Record Number 9 for albany
# Processing Record Number 10 for kaabong
# Processing Record Number 11 for mount isa
# Processing Record Number 12 for carnarvon
# Processing Record Number 13 for custoias
# Processing Record Number 14 for palabuhanratu
# Processing Record Number 15 for sioux lookout
# Processing Record Number 16 for bloemfontein
# Processing Record Number 17 for klaksvik
# Processing Record Number 18 for ushuaia
# Processing Record Number 19 for busselton
# Processing Record Number 20 for taolanaro
# Processing Record Number 21 for sidi bu zayd
# Processing Record Number 22 for pangkalanbuun
# Processing Record Number 23 for umzimvubu
# Processing Record Number 24 for rikitea
# Processing Record Number 25 for cape town
# Processing Record Number 26 for hobart
# Processing Record Number 27 for mehamn
# Processing Record Number 28 for mataura
# Processing Record Number 29 for longyearbyen
# Processing Record Number 30 for georgetown
# Processing Record Number 31 for andevoranto
# Processing Record Number 32 for dunedin
# Processing Record Number 33 for ust-kamchatsk
# Processing Record Number 34 for fort nelson
# Processing Record Number 35 for gornja koprivna
# Processing Record Number 36 for barrow
# Processing Record Number 37 for tasiilaq
# Processing Record Number 38 for porto seguro
# Processing Record Number 39 for limon
# Processing Record Number 40 for illoqqortoormiut
# Processing Record Number 41 for alta floresta
# Processing Record Number 42 for sao joao da barra
# Processing Record Number 43 for montanha
# Processing Record Number 44 for somerset
# Processing Record Number 45 for leh
# Processing Record Number 46 for inhambane
# Processing Record Number 47 for sabathu
# Processing Record Number 48 for grand gaube
# Processing Record Number 49 for iskateley
# Processing Record Number 50 for arraial do cabo
# Processing Record Number 51 for saldanha
# Processing Record Number 52 for faanui
# Processing Record Number 53 for lavrentiya
# Processing Record Number 54 for bambous virieux
# Processing Record Number 55 for thompson
# Processing Record Number 56 for caravelas
# Processing Record Number 57 for beni
# Processing Record Number 58 for bilma
# Processing Record Number 59 for san policarpo
# Processing Record Number 60 for rathdrum
# Processing Record Number 61 for charagua
# Processing Record Number 62 for bluff
# Processing Record Number 63 for itoman
# Processing Record Number 64 for san fernando
# Processing Record Number 65 for guerrero negro
# Processing Record Number 66 for calbuco
# Processing Record Number 67 for salalah
# Processing Record Number 68 for gravdal
# Processing Record Number 69 for saint-pierre
# Processing Record Number 70 for cherskiy
# Processing Record Number 71 for kodiak
# Processing Record Number 72 for bandarbeyla
# Processing Record Number 73 for teguise
# Processing Record Number 74 for santa eulalia del rio
# Processing Record Number 75 for dolbeau
# Processing Record Number 76 for thinadhoo
# Processing Record Number 77 for vanimo
# Processing Record Number 78 for luderitz
# Processing Record Number 79 for aswan
# Processing Record Number 80 for new norfolk
# Processing Record Number 81 for punta arenas
# Processing Record Number 82 for deputatskiy
# Processing Record Number 83 for fortuna
# Processing Record Number 84 for cap malheureux
# Processing Record Number 85 for severo-kurilsk
# Processing Record Number 86 for dzilam gonzalez
# Processing Record Number 87 for hermanus
# Processing Record Number 88 for hofn
# Processing Record Number 89 for yong peng
# Processing Record Number 90 for kaitangata
# Processing Record Number 91 for vila velha
# Processing Record Number 92 for port alfred
# Processing Record Number 93 for taoudenni
# Processing Record Number 94 for margate
# Processing Record Number 95 for provideniya
# Processing Record Number 96 for santa rosa
# Processing Record Number 97 for jamestown
# Processing Record Number 98 for leningradskiy
# Processing Record Number 99 for colborne
# Processing Record Number 100 for vaini
# Processing Record Number 101 for ouesso
# Processing Record Number 102 for banjar
# Processing Record Number 103 for aleksandrov gay
# Processing Record Number 104 for north saint paul
# Processing Record Number 105 for chute-aux-outardes
# Processing Record Number 106 for samfya
# Processing Record Number 107 for kununurra
# Processing Record Number 108 for huanren
# Processing Record Number 109 for busayra
# Processing Record Number 110 for qaanaaq
# Processing Record Number 111 for hilo
# Processing Record Number 112 for black river
# Processing Record Number 113 for noumea
# Processing Record Number 114 for tsihombe
# Processing Record Number 115 for synya
# Processing Record Number 116 for tual
# Processing Record Number 117 for saint anthony
# Processing Record Number 118 for kaeo
# Processing Record Number 119 for obo
# Processing Record Number 120 for surt
# Processing Record Number 121 for paradwip
# Processing Record Number 122 for wairoa
# Processing Record Number 123 for taksimo
# Processing Record Number 124 for saint-philippe
# Processing Record Number 125 for lebu
# Processing Record Number 126 for matsanga
# Processing Record Number 127 for saskylakh
# Processing Record Number 128 for taltal
# Processing Record Number 129 for ilulissat
# Processing Record Number 130 for hamilton
# Processing Record Number 131 for provost
# Processing Record Number 132 for castro
# Processing Record Number 133 for kahului
# Processing Record Number 134 for agadez
# Processing Record Number 135 for belushya guba
# Processing Record Number 136 for grand river south east
# Processing Record Number 137 for grindavik
# Processing Record Number 138 for namibe
# Processing Record Number 139 for port blair
# Processing Record Number 140 for omsukchan
# Processing Record Number 141 for fairbanks
# Processing Record Number 142 for vila franca do campo
# Processing Record Number 143 for mar del plata
# Processing Record Number 144 for licata
# Processing Record Number 145 for ponta do sol
# Processing Record Number 146 for russell
# Processing Record Number 147 for vestmannaeyjar
# Processing Record Number 148 for kenai
# Processing Record Number 149 for lompoc
# Processing Record Number 150 for barentsburg
# Processing Record Number 151 for bokspits
# Processing Record Number 152 for byron bay
# Processing Record Number 153 for chifeng
# Processing Record Number 154 for sabinas
# Processing Record Number 155 for torbay
# Processing Record Number 156 for honiara
# Processing Record Number 157 for awallan
# Processing Record Number 158 for nemuro
# Processing Record Number 159 for roros
# Processing Record Number 160 for najran
# Processing Record Number 161 for leshukonskoye
# Processing Record Number 162 for victoria
# Processing Record Number 163 for cockburn harbour
# Processing Record Number 164 for kajaani
# Processing Record Number 165 for atuona
# Processing Record Number 166 for souillac
# Processing Record Number 167 for upernavik
# Processing Record Number 168 for ulladulla
# Processing Record Number 169 for mogadishu
# Processing Record Number 170 for hobyo
# Processing Record Number 171 for liverpool
# Processing Record Number 172 for ostrovnoy
# Processing Record Number 173 for bethel
# Processing Record Number 174 for lipin bor
# Processing Record Number 175 for nikolskoye
# Processing Record Number 176 for yellowknife
# Processing Record Number 177 for bathsheba
# Processing Record Number 178 for ancud
# Processing Record Number 179 for bengkulu
# Processing Record Number 180 for chokurdakh
# Processing Record Number 181 for laguna
# Processing Record Number 182 for nizwa
# Processing Record Number 183 for lourdes
# Processing Record Number 184 for okhotsk
# Processing Record Number 185 for faya
# Processing Record Number 186 for erzin
# Processing Record Number 187 for don sak
# Processing Record Number 188 for ribeira grande
# Processing Record Number 189 for barcelona
# Processing Record Number 190 for haibowan
# Processing Record Number 191 for las tunas
# Processing Record Number 192 for itaituba
# Processing Record Number 193 for bubaque
# Processing Record Number 194 for samusu
# Processing Record Number 195 for megion
# Processing Record Number 196 for boende
# Processing Record Number 197 for tiksi
# Processing Record Number 198 for yima
# Processing Record Number 199 for itarema
# Processing Record Number 200 for bozovici
# Processing Record Number 201 for kapaa
# Processing Record Number 202 for svetlyy
# Processing Record Number 203 for karachi
# Processing Record Number 204 for ajoloapan
# Processing Record Number 205 for gigmoto
# Processing Record Number 206 for zemio
# Processing Record Number 207 for esperance
# Processing Record Number 208 for emilio carranza
# Processing Record Number 209 for carros
# Processing Record Number 210 for shimoda
# Processing Record Number 211 for tuktoyaktuk
# Processing Record Number 212 for cayenne
# Processing Record Number 213 for tabarqah
# Processing Record Number 214 for makkaveyevo
# Processing Record Number 215 for avera
# Processing Record Number 216 for manicore
# Processing Record Number 217 for puerto ayora
# Processing Record Number 218 for khuzhir
# Processing Record Number 219 for srivardhan
# Processing Record Number 220 for nanaimo
# Processing Record Number 221 for port hardy
# Processing Record Number 222 for remedios
# Processing Record Number 223 for samarai
# Processing Record Number 224 for mrirt
# Processing Record Number 225 for pisco
# Processing Record Number 226 for hithadhoo
# Processing Record Number 227 for asuncion
# Processing Record Number 228 for nizhniy odes
# Processing Record Number 229 for isangel
# Processing Record Number 230 for codrington
# Processing Record Number 231 for poya
# Processing Record Number 232 for butaritari
# Processing Record Number 233 for norman wells
# Processing Record Number 234 for normandin
# Processing Record Number 235 for san angelo
# Processing Record Number 236 for tuyen quang
# Processing Record Number 237 for svetlaya
# Processing Record Number 238 for sakakah
# Processing Record Number 239 for san cristobal
# Processing Record Number 240 for rungata
# Processing Record Number 241 for nanortalik
# Processing Record Number 242 for fenoarivo
# Processing Record Number 243 for christchurch
# Processing Record Number 244 for paradise valley
# Processing Record Number 245 for goksun
# Processing Record Number 246 for ahuimanu
# Processing Record Number 247 for north bend
# Processing Record Number 248 for nokaneng
# Processing Record Number 249 for samana
# Processing Record Number 250 for ozgon
# Processing Record Number 251 for bonthe
# Processing Record Number 252 for ust-nera
# Processing Record Number 253 for palauig
# Processing Record Number 254 for piacabucu
# Processing Record Number 255 for birao
# Processing Record Number 256 for tucano
# Processing Record Number 257 for mariental
# Processing Record Number 258 for tsaratanana
# Processing Record Number 259 for plaridel
# Processing Record Number 260 for palmer
# Processing Record Number 261 for villa constitucion
# Processing Record Number 262 for dikson
# Processing Record Number 263 for artyk
# Processing Record Number 264 for cumaribo
# Processing Record Number 265 for beringovskiy
# Processing Record Number 266 for san patricio
# Processing Record Number 267 for mentougou
# Processing Record Number 268 for port-gentil
# Processing Record Number 269 for fairfield
# Processing Record Number 270 for plettenberg bay
# Processing Record Number 271 for port elizabeth
# Processing Record Number 272 for fort saint john
# Processing Record Number 273 for los llanos de aridane
# Processing Record Number 274 for forestville
# Processing Record Number 275 for port hedland
# Processing Record Number 276 for aguas formosas
# Processing Record Number 277 for vazante
# Processing Record Number 278 for san andres
# Processing Record Number 279 for komsomolskiy
# Processing Record Number 280 for majene
# Processing Record Number 281 for luyang
# Processing Record Number 282 for west bay
# Processing Record Number 283 for coihaique
# Processing Record Number 284 for iqaluit
# Processing Record Number 285 for barrhead
# Processing Record Number 286 for charters towers
# Processing Record Number 287 for general pico
# Processing Record Number 288 for banda aceh
# Processing Record Number 289 for korla
# Processing Record Number 290 for leo
# Processing Record Number 291 for rojhan
# Processing Record Number 292 for sentyabrskiy
# Processing Record Number 293 for tyret pervaya
# Processing Record Number 294 for airai
# Processing Record Number 295 for novokuznetsk
# Processing Record Number 296 for banatski karlovac
# Processing Record Number 297 for franklin
# Processing Record Number 298 for baruun-urt
# Processing Record Number 299 for adrar
# Processing Record Number 300 for santa isabel do rio negro
# Processing Record Number 301 for fare
# Processing Record Number 302 for olafsvik
# Processing Record Number 303 for suntar
# Processing Record Number 304 for dabola
# Processing Record Number 305 for henties bay
# Processing Record Number 306 for andenes
# Processing Record Number 307 for bocaranga
# Processing Record Number 308 for weligama
# Processing Record Number 309 for saint george
# Processing Record Number 310 for amderma
# Processing Record Number 311 for nizhneyansk
# Processing Record Number 312 for puerto madero
# Processing Record Number 313 for huangmei
# Processing Record Number 314 for acarau
# Processing Record Number 315 for port lincoln
# Processing Record Number 316 for alofi
# Processing Record Number 317 for honningsvag
# Processing Record Number 495 for luena
# Processing Record Number 496 for tuatapere
# Processing Record Number 497 for ondorhaan
# Processing Record Number 498 for freeport
# Processing Record Number 499 for inverell
# Processing Record Number 500 for mackay
# Processing Record Number 501 for zyryanka
# Processing Record Number 502 for trencin
# Processing Record Number 503 for khonuu
# Processing Record Number 504 for san borja
# Processing Record Number 505 for tecoanapa
# Processing Record Number 506 for meiktila
# Processing Record Number 507 for hailey
# Processing Record Number 508 for tha mai
# Processing Record Number 509 for kodinar
# Processing Record Number 510 for aklavik
# Processing Record Number 511 for nabire
# Processing Record Number 512 for bhag
# Processing Record Number 513 for northam
# Processing Record Number 514 for praia da vitoria
# Processing Record Number 515 for miri
# Processing Record Number 516 for port shepstone
# Processing Record Number 517 for ouango
# Processing Record Number 518 for talwara
# Processing Record Number 519 for comodoro rivadavia
# Processing Record Number 520 for khasan
# Processing Record Number 521 for denau
# Processing Record Number 522 for kanevskaya
# Processing Record Number 523 for jacareacanga
# Processing Record Number 524 for gornopravdinsk
# Processing Record Number 525 for port macquarie
# Processing Record Number 526 for marcona
# Processing Record Number 527 for jibuti
# Processing Record Number 528 for mananjary
# Processing Record Number 529 for winnemucca
# Processing Record Number 530 for dukat
# Processing Record Number 531 for bilibino
# Processing Record Number 532 for merauke
# Processing Record Number 533 for ahipara
# Processing Record Number 534 for mallama
# Processing Record Number 535 for yulara
# Processing Record Number 536 for plainview
# Processing Record Number 537 for ojinaga
# Processing Record Number 538 for lasa
# Processing Record Number 539 for eskasem
# Processing Record Number 540 for tigil
# Processing Record Number 541 for attawapiskat
# Processing Record Number 542 for lagos
# Processing Record Number 543 for juba
# Processing Record Number 544 for kathu
# Processing Record Number 545 for dire
# Processing Record Number 546 for petropavlovsk-kamchatskiy
# Processing Record Number 547 for chicla
# Processing Record Number 548 for odweyne
# Processing Record Number 549 for mazagao
# Processing Record Number 550 for makakilo city
# Processing Record Number 551 for harper
# Processing Record Number 552 for healdsburg
# Processing Record Number 553 for heihe
# Processing Record Number 554 for turangi
# Processing Record Number 555 for orange cove
# Processing Record Number 556 for galyugayevskaya
# Processing Record Number 557 for kidal
# Processing Record Number 558 for mikhaylovskoye
# Processing Record Number 559 for huancayo
# Processing Record Number 560 for porto novo
# Processing Record Number 561 for cockburn town
# Processing Record Number 562 for kalmunai
# Processing Record Number 563 for ilo
# Processing Record Number 564 for kutum
# Processing Record Number 565 for ambon
# Processing Record Number 566 for khandyga
# Processing Record Number 567 for estelle
# Processing Record Number 568 for cumbernauld
# Processing Record Number 569 for bonavista
# Processing Record Number 570 for yinchuan
# Processing Record Number 571 for lorengau
# Processing Record Number 572 for yumen
# Processing Record Number 573 for moerai
# Processing Record Number 574 for richards bay
# Processing Record Number 575 for colon
# Processing Record Number 576 for kourou
# Processing Record Number 577 for kibaya
# Processing Record Number 578 for suba
# Processing Record Number 579 for ayr
# Processing Record Number 580 for pahrump
# Processing Record Number 581 for tostamaa
# Processing Record Number 582 for ambulu

# %%
city_data_df = pd.DataFrame(city_api_data)
output_csv = "./city_output_data/city_data.csv"
city_data_df.to_csv(output_csv,index_label="City Number")
print(city_data_df.count())
city_data_df.head()
# Out:
# City          524
# Lat           524
# Lon           524
# Temp          524
# Humidity      524
# Cloudiness    524
# Wind Speed    524
# Country       524
# dtype: int64
#           City      Lat       Lon   Temp  Humidity  Cloudiness  Wind Speed  \
# 0       avarua -21.2078 -159.7750  78.80        65          85       18.34
# 1       baykit  61.6700   96.3700  56.86        67          72       10.36
# 2         bako   5.7833   36.5667  63.81        57         100        3.47
# 3  east london -33.0153   27.9116  73.17        34          98       14.83
# 4   bredasdorp -34.5322   20.0403  50.00        66         100        3.36
#
#   Country
# 0      CK
# 1      RU
# 2      ET
# 3      ZA
# 4      ZA

# %%
# Latitude vs Temp scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Temp"])
plt.title("Latitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.savefig("city_output_data/Scatter_1.png")

# %% [markdown]
# This plot shows that as you get closer to the equator (Latitude approaches 0), the average temperature in the selected cities rises significantly.

# %%
# Latitude vs Humidity scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"])
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("city_output_data/Scatter_2.png")

# %% [markdown]
# This plot shows the humidity in each selected city. There does not appear to be a strong correlation between latitutde and humidity shown on this graph.

# %%
# Latitude vs Cloudiness scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"])
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness)")
plt.savefig("city_output_data/Scatter_3.png")

# %% [markdown]
# This plot shows the cloudiness of all selected cities. There does not appear to be any correlation between cloudiness and latitude show on this graph, however, many cities fall within the four groups of 0, 40, 75, and 100 cloudiness, respectively.

# %%
# Latitude vs Wind Speed scatter plot
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"])
plt.title("Latitude vs Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
plt.savefig("city_output_data/Scatter_4.png")

# %% [markdown]
# This plot shows the wind speed of each selected city. There does not appear to be a correlation between wind speed and latitude shown on this graph.

# %%
# Split data into Northern and Southern Hemispheres
northern_data = city_data_df.loc[city_data_df["Lat"] > 0]
southern_data = city_data_df.loc[city_data_df["Lat"] < 0]

# %%
# Northern Hemisphere Temp vs Latitude scatter plot and linear regression
fig5,ax5 = plt.subplots()
ax5.scatter(northern_data["Lat"],northern_data["Temp"])
plt.title("Northern Hemisphere Latitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
# regression line
(slope,intercept,_,_,_) = st.linregress(northern_data["Lat"],northern_data["Temp"])
fit = slope * northern_data["Lat"] + intercept
ax5.plot(northern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression1.png")

# %%
# Southern Hemisphere Temp vs Latitude scatter plot and linear regression
fig6,ax6 = plt.subplots()
ax6.scatter(southern_data["Lat"],southern_data["Temp"])
plt.title("Southern Hemisphere Latitude vs Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
# regression line
(slope,intercept,_,_,_) = st.linregress(southern_data["Lat"],southern_data["Temp"])
fit = slope * southern_data["Lat"] + intercept
ax6.plot(southern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression2.png")

# %% [markdown]
# These 2 plots show the relation between temperature and latitude for the northern and southern hemispheres. It is clear that each hemisphere's temperature significantly increases as it approaches the equator (Latitude of 0).

# %%
# Northern Hemisphere Humidity vs Latitude scatter plot and linear regression
fig7,ax7 = plt.subplots()
ax7.scatter(northern_data["Lat"],northern_data["Humidity"])
plt.title("Northern Hemisphere Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# regression line
(slope,intercept,_,_,_) = st.linregress(northern_data["Lat"],northern_data["Humidity"])
fit = slope * northern_data["Lat"] + intercept
ax7.plot(northern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression3.png")

# %%
# Southern Hemisphere Humidity vs Latitude scatter plot and linear regression
fig8,ax8 = plt.subplots()
ax8.scatter(southern_data["Lat"],southern_data["Humidity"])
plt.title("Southern Hemisphere Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
# regression line
(slope,intercept,_,_,_) = st.linregress(southern_data["Lat"],southern_data["Humidity"])
fit = slope * southern_data["Lat"] + intercept
ax8.plot(southern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression4.png")

# %% [markdown]
# These two plots show the relation between latitude and humidity for the northern and southern hemispheres. The humidity in both hemispheres appears to stay consistent regardless of the distance to the equator.

# %%
# Northern Hemisphere Cloudiness vs Latitude scatter plot and linear regression
fig9,ax9 = plt.subplots()
ax9.scatter(northern_data["Lat"],northern_data["Cloudiness"])
plt.title("Northern Hemisphere Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# regression line
(slope,intercept,_,_,_) = st.linregress(northern_data["Lat"],northern_data["Cloudiness"])
fit = slope * northern_data["Lat"] + intercept
ax9.plot(northern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression5.png")

# %%
# Southern Hemisphere Cloudiness vs Latitude scatter plot and linear regression
fig10,ax10 = plt.subplots()
ax10.scatter(southern_data["Lat"],southern_data["Cloudiness"])
plt.title("Southern Hemisphere Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
# regression line
(slope,intercept,_,_,_) = st.linregress(southern_data["Lat"],southern_data["Cloudiness"])
fit = slope * southern_data["Lat"] + intercept
ax10.plot(southern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression6.png")

# %% [markdown]
# These graphs show the relation between latitude and cloudiness in the northern and southern hemispheres. There does not appear to be a strong correlation between the two variables.

# %%
# Northern Hemisphere Wind Speed vs Latitude scatter plot and linear regression
fig11,ax11 = plt.subplots()
ax11.scatter(northern_data["Lat"],northern_data["Wind Speed"])
plt.title("Northern Hemisphere Latitude vs Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
# regression line
(slope,intercept,_,_,_) = st.linregress(northern_data["Lat"],northern_data["Wind Speed"])
fit = slope * northern_data["Lat"] + intercept
ax11.plot(northern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression7.png")

# %%
# Southern Hemisphere Wind Speed vs Latitude scatter plot and linear regression
fig12,ax12 = plt.subplots()
ax12.scatter(southern_data["Lat"],southern_data["Wind Speed"])
plt.title("Southern Hemisphere Latitude vs Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (MPH)")
# regression line
(slope,intercept,_,_,_) = st.linregress(southern_data["Lat"],southern_data["Wind Speed"])
fit = slope * southern_data["Lat"] + intercept
ax12.plot(southern_data["Lat"],fit,"r")

plt.savefig("city_output_data/Regression8.png")

# %% [markdown]
# These two graphs show the wind speed compared to latitude of cities in the northern and southern hemispheres. There doesn't appear to be correlation based on these graphs.
